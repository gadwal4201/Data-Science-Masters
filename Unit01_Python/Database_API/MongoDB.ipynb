# %% [markdown]
# # MongoDB Connect with Python

# %%
# mongodb+srv://gadwalpankaj1435:<F9KVwAH4knBM6qYI>@cluster0.5ghnxfs.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0

# %%
import pymongo

# %%
client = pymongo.MongoClient("mongodb+srv://gadwalpankaj1435:<F9KVwAH4knBM6qYI>@cluster0.5ghnxfs.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
db = client.test

# %%
db
# Out:
# Database(MongoClient(host=['ac-abhjmbz-shard-00-00.5ghnxfs.mongodb.net:27017', 'ac-abhjmbz-shard-00-01.5ghnxfs.mongodb.net:27017', 'ac-abhjmbz-shard-00-02.5ghnxfs.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Cluster0', authsource='admin', replicaset='atlas-8pp78a-shard-0', tls=True), 'test')

# %%
db = client["pwskills"]

# %%
data = {
    "name": "Pankaj Gadwal",
    "class": "Data Science Masters",
    "time": "Flexi"
}

# %%
coll_pwskills = db["my_record"]

# %%
coll_pwskills.insert_one(data)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 coll_pwskills.insert_one(data)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pymongo\collection.py:658, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     654     document["_id"] = ObjectId()  # type: ignore[index]
#     656 write_concern = self._write_concern_for(session)
#     657 return InsertOneResult(
# --> 658     self._insert_one(
#     659         document,
#     660         ordered=True,
#     661         write_concern=write_concern,
#     662         op_id=None,
#     663         bypass_doc_val=bypass_document_validation,
#     664         session=session,
#     665         comment=comment,
#     666     ),
#     667     write_concern.acknowledged,
#     668 )
#
# ...
