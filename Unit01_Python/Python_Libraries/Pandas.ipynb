# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
# pip install pandas

# %%
df = pd.read_csv("annual-enterprise-survey-2024-financial-year-provisional.csv")  # Read a CSV file into a DataFrame

# %%
df.head()  # Display the first few rows of the DataFrame
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2024                     Level 1                99999       All industries
# 1  2024                     Level 1                99999       All industries
# 2  2024                     Level 1                99999       All industries
# 3  2024                     Level 1                99999       All industries
# 4  2024                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
df.describe()  # Get a statistical summary of the DataFrame
# Out:
#                Year
# count  55620.000000
# mean    2018.500000
# std        3.452084
# min     2013.000000
# 25%     2015.750000
# 50%     2018.500000
# 75%     2021.250000
# max     2024.000000

# %%
df.tail()  # Display the last few rows of the DataFrame
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 55615  2013                     Level 3                 ZZ11
# 55616  2013                     Level 3                 ZZ11
# 55617  2013                     Level 3                 ZZ11
# 55618  2013                     Level 3                 ZZ11
# 55619  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 55615  Food product manufacturing  Percentage           H37
# 55616  Food product manufacturing  Percentage           H38
# 55617  Food product manufacturing  Percentage           H39
# 55618  Food product manufacturing  Percentage           H40
# 55619  Food product manufacturing  Percentage           H41
#
#                              Variable_name Variable_category Value  \
# 55615                          Quick ratio  Financial ratios    52
# 55616  Margin on sales of goods for resale  Financial ratios    40
# ...

# %%
type(df)  # Check the type of the object
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns  # Get the column names of the DataFrame
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
list(df.columns)  # Convert the column names to a list
# Out:
# ['Year',
#  'Industry_aggregation_NZSIOC',
#  'Industry_code_NZSIOC',
#  'Industry_name_NZSIOC',
#  'Units',
#  'Variable_code',
#  'Variable_name',
#  'Variable_category',
#  'Value',
#  'Industry_code_ANZSIC06']

# %%
df['Industry_name_NZSIOC']  # Access a specific column in the DataFrame
# Out:
# 0                    All industries
# 1                    All industries
# 2                    All industries
# 3                    All industries
# 4                    All industries
#                     ...
# 55615    Food product manufacturing
# 55616    Food product manufacturing
# 55617    Food product manufacturing
# 55618    Food product manufacturing
# 55619    Food product manufacturing
# Name: Industry_name_NZSIOC, Length: 55620, dtype: object

# %%
type(df['Industry_name_NZSIOC'])  # Check the type of the column accessed
# Out:
# pandas.core.series.Series

# %%
list(df['Industry_name_NZSIOC'].head())  # Convert the column to a list
# Out:
# ['All industries',
#  'All industries',
#  'All industries',
#  'All industries',
#  'All industries']

# %%
df[['Industry_name_NZSIOC']].head()  # Access multiple columns in the DataFrame
# Out:
#   Industry_name_NZSIOC
# 0       All industries
# 1       All industries
# 2       All industries
# 3       All industries
# 4       All industries

# %%
type(df[['Industry_name_NZSIOC']])  # Check the type of the DataFrame with a single column
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns  # Get the column names of the DataFrame
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
df[['Industry_name_NZSIOC', 'Units']].head()  # Access multiple columns in the DataFrame
# Out:
#   Industry_name_NZSIOC               Units
# 0       All industries  Dollars (millions)
# 1       All industries  Dollars (millions)
# 2       All industries  Dollars (millions)
# 3       All industries  Dollars (millions)
# 4       All industries  Dollars (millions)

# %%
df.dtypes  # Get the data types of the columns in the DataFrame
# Out:
# Year                            int64
# Industry_aggregation_NZSIOC    object
# Industry_code_NZSIOC           object
# Industry_name_NZSIOC           object
# Units                          object
# Variable_code                  object
# Variable_name                  object
# Variable_category              object
# Value                          object
# Industry_code_ANZSIC06         object
# dtype: object

# %%
url_data = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015.html")

# %%
type(url_data)  # Check the type of the object returned by read_html
# Out:
# list

# %%
df1 = url_data[0]  # Access the first table from the list of DataFrames

# %%
df1
# Out:
#       Eastern Conference                   W                   L  \
# 0      Atlantic Division   Atlantic Division   Atlantic Division
# 1       Toronto Raptors*                  49                  33
# 2        Boston Celtics*                  40                  42
# 3         Brooklyn Nets*                  38                  44
# 4     Philadelphia 76ers                  18                  64
# 5        New York Knicks                  17                  65
# 6       Central Division    Central Division    Central Division
# 7   Cleveland Cavaliers*                  53                  29
# 8         Chicago Bulls*                  50                  32
# 9       Milwaukee Bucks*                  41                  41
# 10        Indiana Pacers                  38                  44
# 11       Detroit Pistons                  32                  50
# 12    Southeast Division  Southeast Division  Southeast Division
# ...

# %%
df2 = url_data[1]  # Access the second table from the list of DataFrames

# %%
df2
# Out:
#          Western Conference                   W                   L  \
# 0        Northwest Division  Northwest Division  Northwest Division
# 1   Portland Trail Blazers*                  51                  31
# 2     Oklahoma City Thunder                  45                  37
# 3                 Utah Jazz                  38                  44
# 4            Denver Nuggets                  30                  52
# 5    Minnesota Timberwolves                  16                  66
# 6          Pacific Division    Pacific Division    Pacific Division
# 7    Golden State Warriors*                  67                  15
# 8     Los Angeles Clippers*                  56                  26
# 9              Phoenix Suns                  39                  43
# 10         Sacramento Kings                  29                  53
# 11       Los Angeles Lakers                  21                  61
# 12       Southwest Division  Southwest Division  Southwest Division
# ...

# %%
url_data[3]
# Out:
#       Rk                     Team   G     MP    FG   FGA    FG%   3P   3PA  \
# 0    1.0                Utah Jazz  82  240.3  35.8  80.3  0.446  7.4  20.4
# 1    2.0       Memphis Grizzlies*  82  242.7  36.0  81.5  0.442  8.1  23.0
# 2    3.0       San Antonio Spurs*  82  243.4  37.1  83.7  0.444  6.8  18.9
# 3    4.0           Indiana Pacers  82  242.1  36.0  82.7  0.435  7.2  20.9
# 4    5.0           Atlanta Hawks*  82  240.6  36.5  83.1  0.439  8.8  25.8
# 5    6.0        Charlotte Hornets  82  242.7  36.8  83.7  0.440  7.9  22.1
# 6    7.0               Miami Heat  82  240.6  36.1  79.5  0.454  8.1  23.0
# 7    8.0         Milwaukee Bucks*  82  243.0  35.6  81.5  0.437  8.2  24.1
# 8    9.0      Washington Wizards*  82  243.4  36.2  83.5  0.433  8.0  23.0
# 9   10.0           Chicago Bulls*  82  242.4  37.7  86.7  0.435  6.6  19.6
# 10  11.0    New Orleans Pelicans*  82  241.2  37.9  83.1  0.456  6.5  19.6
# ...

# %%
df1.to_csv("Players_2015.csv")  # Save the first DataFrame to an Excel file

# %%
df1.to_excel("Players_2015.xlsx",index=False)  # Save the first DataFrame to an Excel file
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df1.to_excel("Players_2015.xlsx",index=False)  # Save the first DataFrame to an Excel file
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
pip install openpyxl  # Install the openpyxl library to handle Excel files
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Invalid requirement: '#': Expected package name at the start of dependency specifier
#     #
#     ^

# %%
# !pip install openpyxl  # Install the openpyxl library to handle Excel files
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Invalid requirement: '#': Expected package name at the start of dependency specifier
#     #
#     ^
